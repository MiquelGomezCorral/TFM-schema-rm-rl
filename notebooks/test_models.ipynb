# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.config import Configuration
import dotenv

dotenv.load_dotenv()
CONFIG = Configuration()

# %%
from src.engines import (
    OpenCodeEngine,
)
from src.models import EnvironmentDescription, Proposition

from pathlib import Path


environment = EnvironmentDescription(
    source=Path('examples/multitaxi/environment.md'),
    title='Multitaxi',
    markdown='hi, this is a simple environment for testing the OpenCodeEngine',
    propositions=[
        Proposition(
            identifier='hello_world',   
            description='say hello world, my name is: <you name>',
            line=1
        )
    ]
)  

engine = OpenCodeEngine(
    environment, 
    # Slow
    # 'nemotron-3.5-lightning-free'
    # 'nemotron-3-ultra-free'

    # Fast
	# 'big-pickle'
    # 'mimo-v2.5-free'


    # no working
    # 'ling-3.0-flash-fin-free'
    # 'muse-spark-1.3-contributor-free'

)

print('-')
engine.propose_task(
    'say hello world, my name is: <you name>',
    'Hy my name is maikol'
)
# Out:
# -
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# File ~/Documents/Master/TFM/TFM-schema-rm-rl/app/src/engines/openai_engine.py:116, in GenericEngine._request_structured(self, system, user, schema, name)
#     115 try:
# --> 116     return self._request(self.model, system, user, schema, name)
#     117 except Exception as error:
#
# File ~/Documents/Master/TFM/TFM-schema-rm-rl/app/src/engines/openai_engine.py:206, in _request_chat_completions(client, model, system, user, schema, name)
#     198 def _request_chat_completions(
#     199     client: OpenAI,
#     200     model: str,
#    (...)    204     name: str,
#     205 ) -> str:
# --> 206     response = client.chat.completions.create(
#     207         model=model,
#     208         messages=[{"role": "system", "content": system}, {"role": "user", "content": user}],
#     209         response_format={
# ...
